# %%
#5 different functions of strings in python

# %%
Name="shri krishna"

# %%
Name.find("r")
# Out:
# 2

# %%
Fruit="banana"

# %%
Fruit.isalpha()
# Out:
# True

# %%
Fruit.isdigit()
# Out:
# False

# %%
Fruit.upper()
# Out:
# 'BANANA'

# %%
Std="I love my INDIA"

# %%
Std.swapcase()
# Out:
# 'i LOVE MY india'

# %%
Car="marutisuzuki800"

# %%
Car.isalnum()
# Out:
# True

# %%
# 5 different functions of list object in python

# %%
lst=[9,8,7,6,"hi","hello","good bye"]

# %%
lst.reverse()

# %%
print (lst)
# Out:
# ['good bye', 'hello', 'hi', 6, 7, 8, 9]

# %%
A=[4,7,6,3,8]

# %%
A.sort()

# %%
print (A)
# Out:
# [3, 4, 6, 7, 8]

# %%
A.clear()

# %%
print (A)
# Out:
# []

# %%
Color=["Black","blue","orange","red","yellow","green"]

# %%
Color.copy()
# Out:
# ['Black', 'blue', 'orange', 'red', 'yellow', 'green']

# %%
Color.pop(3)
# Out:
# 'red'

# %%
print (Color)
# Out:
# ['Black', 'blue', 'orange', 'yellow', 'green']

# %%
#Experiment with 5 default functions of Dictionary

# %%
Std={"name":"Arun","sem":5,"grade":"good"}

# %%
Std.popitem()
# Out:
# ('grade', 'good')

# %%
print (Std)
# Out:
# {'name': 'Arun', 'sem': 5}

# %%
Std.copy()
# Out:
# {'name': 'Arun', 'sem': 5}

# %%
Std.clear()

# %%
print (Std)
# Out:
# {}

# %%
Cal={"date":25,"day": "Sunday","month":"Oct","year":2001}

# %%
print (Cal)
# Out:
# {'date': 25, 'day': 'Sunday', 'month': 'Oct', 'year': 2001}

# %%
Cal.items()
# Out:
# dict_items([('date', 25), ('day', 'Sunday'), ('month', 'Oct'), ('year', 2001)])

# %%
Cal.update({"time":12.35})

# %%
print (Cal)
# Out:
# {'date': 25, 'day': 'Sunday', 'month': 'Oct', 'year': 2001, 'time': 12.35}
